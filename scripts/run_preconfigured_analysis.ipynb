# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os 
sys.path.append("../")
import numpy as np

# %%
from microfit.analysis import MultibandAnalysis
import logging

config_file = "../config_files/full_ana_with_detvars.toml"

analysis = MultibandAnalysis.from_toml(
    config_file,
    logging_level=logging.DEBUG,
    overwrite_cached_df=False,
    overwrite_cached_df_detvars=False,
    output_dir="../full_ana_output/",
)
# Out:
# DEBUG:microfit.analysis:Creating RunHistGenerator from config: {'load_runs': {'run_numbers': ['3_crt', '4d', '5'], 'data': 'muon_sideband', 'truth_filtered_sets': ['nue', 'drt'], 'loadshowervariables': False, 'loadsystematics': True, 'use_bdt': False, 'loadnumuvariables': True, 'load_crt_vars': True, 'numupresel': True, 'enable_cache': True, 'blinded': False}, 'detvars': {'truth_filtered_sets': ['nue', 'nc_pi0']}, 'channel': [{'variable': 'neutrino_energy', 'n_bins': 14, 'limits': [0.15, 1.55], 'selection': 'NUMUCRTNP0PI', 'preselection': 'NUMUCRT', 'variable_tex': 'Neutrino Reconstructed Energy (GeV)'}, {'variable': 'neutrino_energy', 'n_bins': 14, 'limits': [0.15, 1.55], 'selection': 'NUMUCRT0P0PI', 'preselection': 'NUMUCRT', 'variable_tex': 'Neutrino Reconstructed Energy (GeV)'}, {'variable': 'neutrino_energy', 'n_bins': 14, 'limits': [0.15, 1.55], 'selection': 'NUMUCRT', 'preselection': 'NUMUCRT', 'variable_tex': 'Neutrino Reconstructed Energy (GeV)'}]}
# INFO:microfit.analysis:Creating RunHistGenerator for channels ['NUMUCRTNP0PI', 'NUMUCRT0P0PI', 'NUMUCRT']
# INFO:microfit.analysis:Loading data...
# Output dir from config overridden to: ../full_ana_output/
# Loading run 3_crt
# Loading run 4d
# Loading run 5
# WARNING: drt has no weightsFlux universes, replacing with ones
# WARNING: drt has no weightsReint universes, replacing with ones
# INFO:microfit.analysis:Loading detvar data... This can take some time.
# DEBUG:microfit.analysis:Detvar config: {'run_numbers': ['3_crt', '4d', '5'], 'data': 'muon_sideband', 'truth_filtered_sets': ['nue', 'nc_pi0'], 'loadshowervariables': False, 'loadsystematics': False, 'use_bdt': False, 'loadnumuvariables': True, 'load_crt_vars': True, 'numupresel': True, 'enable_cache': True, 'blinded': False, 'overwrite': False, 'binning': MultiChannelBinning(binnings=[Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='NUMUCRTNP0PI', variable_tex='Neutrino Reconstructed Energy (GeV)', is_log=False, selection_query='nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5. and nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and n_muons_tot > 0 and n_muons_tot == 1 and n_showers_tot == 0 and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5. and n_protons_tot > 0', selection_key='NUMUCRTNP0PI', preselection_key='NUMUCRT', selection_tex='$1\\mu$Np0$\\pi$ selection w/ CRT', selection_tex_short='$1\\mu$Np0$\\pi$ w/ CRT'), Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='NUMUCRT0P0PI', variable_tex='Neutrino Reconstructed Energy (GeV)', is_log=False, selection_query='nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5. and nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and n_muons_tot > 0 and n_muons_tot == 1 and n_showers_tot == 0 and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5. and n_protons_tot == 0 and topological_score > 0.2', selection_key='NUMUCRT0P0PI', preselection_key='NUMUCRT', selection_tex='$1\\mu$0p0$\\pi$ selection w/ CRT', selection_tex_short='$1\\mu$0p0$\\pi$ w/ CRT'), Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='NUMUCRT', variable_tex='Neutrino Reconstructed Energy (GeV)', is_log=False, selection_query='nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5. and nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and n_muons_tot > 0 and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5.', selection_key='NUMUCRT', preselection_key='NUMUCRT', selection_tex='$\\nu_{\\mu}$ selection w/ CRT', selection_tex_short='$\\nu_{\\mu}$ w/ CRT')], is_log=False), 'load_lee': False, 'make_plots': True, 'enable_detvar_cache': True, 'show_plots': False, 'detvar_cache_dir': '/nashome/a/atrettin/PELEE/full_ana_output/detvar_cache', 'plot_output_dir': '/nashome/a/atrettin/PELEE/full_ana_output/detvar_plots'}
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Loading devar histograms from file: /nashome/a/atrettin/PELEE/full_ana_output/detvar_cache/run_3_crt4d5_NUMUCRTNP0PI_NUMUCRT0P0PI_NUMUCRT_muon_sideband.json
# Making plots for mc
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for nue
# Making plots for nc_pi0
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for mc
# Making plots for nue
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for nc_pi0
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for mc
# Making plots for nue
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for nc_pi0
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# DEBUG:microfit.analysis:Creating RunHistGenerator from config: {'load_runs': {'run_numbers': ['3_crt', '4d', '5'], 'data': 'two_shr_sideband', 'truth_filtered_sets': ['nue', 'drt'], 'loadpi0variables': True, 'loadshowervariables': True, 'loadrecoveryvars': False, 'loadsystematics': True, 'load_crt_vars': True, 'load_lee': False, 'enable_cache': True, 'blinded': False}, 'detvars': {'truth_filtered_sets': ['nue', 'nc_pi0']}, 'channel': [{'variable': 'reco_e', 'n_bins': 10, 'limits': [0.15, 1.0], 'selection': 'ZPLOOSESELTWOSHR', 'preselection': 'ZPTwoShrCRT', 'label': 'TWOSHR', 'variable_tex': 'Neutrino Reconstructed Energy (GeV)'}]}
# INFO:microfit.analysis:Creating RunHistGenerator for channels ['TWOSHR']
# INFO:microfit.analysis:Loading data...
# Loading run 3_crt
# Loading run 4d
# Loading run 5
# WARNING: drt has no weightsFlux universes, replacing with ones
# WARNING: drt has no weightsReint universes, replacing with ones
# INFO:microfit.analysis:Loading detvar data... This can take some time.
# DEBUG:microfit.analysis:Detvar config: {'run_numbers': ['3_crt', '4d', '5'], 'data': 'two_shr_sideband', 'truth_filtered_sets': ['nue', 'nc_pi0'], 'loadpi0variables': True, 'loadshowervariables': True, 'loadrecoveryvars': False, 'loadsystematics': False, 'load_crt_vars': True, 'load_lee': False, 'enable_cache': True, 'blinded': False, 'overwrite': False, 'binning': MultiChannelBinning(binnings=[Binning(variable='reco_e', bin_edges=array([0.15 , 0.235, 0.32 , 0.405, 0.49 , 0.575, 0.66 , 0.745, 0.83 ,
#        0.915, 1.   ]), label='TWOSHR', variable_tex='Neutrino Reconstructed Energy (GeV)', is_log=False, selection_query='nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_tracks_contained == 0 and n_showers_contained > 1 and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5. and nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_tracks_contained == 0 and n_showers_contained > 1 and CosmicIPAll3D > 10. and CosmicDirAll3D > -0.9 and CosmicDirAll3D < 0.9 and shrmoliereavg < 15 and subcluster > 4 and trkfit < 0.65 and secondshower_Y_nhit < 50 and shr_trk_sce_start_y > -100 and shr_trk_sce_start_y < 100 and shr_trk_sce_end_y > -100 and shr_trk_sce_end_y < 100  and shr_trk_len < 300. and (n_tracks_tot == 0 or (n_tracks_tot>0 and tk1sh1_angle_alltk>-0.9)) and n_tracks_contained == 0', selection_key='ZPLOOSESELTWOSHR', preselection_key='ZPTwoShrCRT', selection_tex='1e0p loose sel. 2+ shr', selection_tex_short='1e0p loose 2+ shr')], is_log=False), 'make_plots': True, 'enable_detvar_cache': True, 'show_plots': False, 'detvar_cache_dir': '/nashome/a/atrettin/PELEE/full_ana_output/detvar_cache', 'plot_output_dir': '/nashome/a/atrettin/PELEE/full_ana_output/detvar_plots'}
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Loading devar histograms from file: /nashome/a/atrettin/PELEE/full_ana_output/detvar_cache/run_3_crt4d5_TWOSHR_two_shr_sideband.json
# Making plots for mc
# Making plots for nue
# Making plots for nc_pi0
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# DEBUG:microfit.analysis:Creating RunHistGenerator from config: {'mc_hist_generator_cls': 'SignalOverBackgroundGenerator', 'load_runs': {'run_numbers': ['1', '2', '3', '4b', '4c', '4d', '5'], 'data': 'bnb', 'truth_filtered_sets': ['nue', 'drt'], 'loadpi0variables': True, 'loadshowervariables': True, 'loadrecoveryvars': True, 'loadsystematics': True, 'load_lee': True, 'use_new_signal_model': True, 'enable_cache': True, 'blinded': True}, 'detvars': {'truth_filtered_sets': ['nue', 'nc_pi0'], 'extra_selection_query': '(mcf_pass_ncpi0 == 1 or (abs(nu_pdg) == 12 and ccnc == 0))', 'misc_background_query': '(mcf_pass_ncpi0 != 1 or (abs(nu_pdg) != 12 and ccnc != 0))', 'misc_background_error_frac': 0.2}, 'parameter': [{'name': 'signal_strength', 'value': 1.0, 'bounds': [0.0, 10.0]}], 'channel': [{'variable': 'shr_energy_tot_cali', 'n_bins': 14, 'limits': [0.05, 1.55], 'selection': 'NPBDT', 'preselection': 'NP', 'label': 'NPBDT_SHR_E', 'variable_tex': 'Reconstructed Shower Energy (GeV)'}, {'variable': 'shr_energy_tot_cali', 'n_bins': 14, 'limits': [0.05, 1.55], 'selection': 'ZPBDT', 'preselection': 'ZP', 'label': 'ZPBDT_SHR_E', 'variable_tex': 'Reconstructed Shower Energy (GeV)'}, {'variable': 'shr_theta', 'n_bins': 14, 'limits': [0.0, 3.141], 'selection': 'NPBDT', 'preselection': 'NP', 'label': 'NPBDT_SHR_THETA', 'variable_tex': 'Reconstructed Shower $\\theta$'}, {'variable': 'shr_theta', 'n_bins': 14, 'limits': [0.0, 3.141], 'selection': 'ZPBDT', 'preselection': 'ZP', 'label': 'ZPBDT_SHR_THETA', 'variable_tex': 'Reconstructed Shower $\\theta$'}]}
# INFO:microfit.analysis:Creating RunHistGenerator for channels ['NPBDT_SHR_E', 'ZPBDT_SHR_E', 'NPBDT_SHR_THETA', 'ZPBDT_SHR_THETA']
# INFO:microfit.analysis:Loading data...
# Loading run 1
# Loading run 2
# Loading run 3
# Loading run 4b
# Loading run 4c
# Loading run 4d
# Loading run 5
# WARNING: drt has no weightsFlux universes, replacing with ones
# WARNING: drt has no weightsReint universes, replacing with ones
# INFO:microfit.analysis:Loading detvar data... This can take some time.
# DEBUG:microfit.analysis:Detvar config: {'run_numbers': ['1', '2', '3', '4b', '4c', '4d', '5'], 'data': 'bnb', 'truth_filtered_sets': ['nue', 'nc_pi0'], 'loadpi0variables': True, 'loadshowervariables': True, 'loadrecoveryvars': True, 'loadsystematics': False, 'load_lee': False, 'enable_cache': True, 'blinded': True, 'overwrite': False, 'extra_selection_query': '(mcf_pass_ncpi0 == 1 or (abs(nu_pdg) == 12 and ccnc == 0))', 'binning': MultiChannelBinning(binnings=[Binning(variable='shr_energy_tot_cali', bin_edges=array([0.05      , 0.15714286, 0.26428571, 0.37142857, 0.47857143,
#        0.58571429, 0.69285714, 0.8       , 0.90714286, 1.01428571,
#        1.12142857, 1.22857143, 1.33571429, 1.44285714, 1.55      ]), label='NPBDT_SHR_E', variable_tex='Reconstructed Shower Energy (GeV)', is_log=False, selection_query='nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_tracks_contained > 0 and nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_tracks_contained > 0 and CosmicIPAll3D > 10. and trkpid < 0.02 and hits_ratio > 0.50 and shrmoliereavg < 9 and subcluster > 4 and trkfit < 0.65 and tksh_distance < 6.0 and (shr_tkfit_nhits_tot > 1 and shr_tkfit_dedx_max > 0.5 and shr_tkfit_dedx_max < 5.5) and tksh_angle > -0.9 and shr_trk_len < 300. and pi0_score > 0.67 and nonpi0_score > 0.70 and n_showers_contained == 1', selection_key='NPBDT', preselection_key='NP', selection_tex='1eNp BDT sel.', selection_tex_short='1eNp BDT'), Binning(variable='shr_energy_tot_cali', bin_edges=array([0.05      , 0.15714286, 0.26428571, 0.37142857, 0.47857143,
#        0.58571429, 0.69285714, 0.8       , 0.90714286, 1.01428571,
#        1.12142857, 1.22857143, 1.33571429, 1.44285714, 1.55      ]), label='ZPBDT_SHR_E', variable_tex='Reconstructed Shower Energy (GeV)', is_log=False, selection_query='nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_tracks_contained == 0 and nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_showers_contained == 1 and CosmicIPAll3D > 10. and CosmicDirAll3D > -0.9 and CosmicDirAll3D < 0.9 and shrmoliereavg < 15 and subcluster > 4 and trkfit < 0.65 and secondshower_Y_nhit < 50 and shr_trk_sce_start_y > -100 and shr_trk_sce_start_y < 80 and shr_trk_sce_end_y > -100 and shr_trk_sce_end_y < 100  and shr_trk_len < 300. and (n_tracks_tot == 0 or (n_tracks_tot>0 and tk1sh1_angle_alltk>-0.9)) and bkg_score > 0.72 and n_tracks_contained == 0 and (n_tracks_tot == 0 or (n_tracks_tot>0 and tk1sh1_angle_alltk>-0.9))', selection_key='ZPBDT', preselection_key='ZP', selection_tex='1e0p BDT sel.', selection_tex_short='1e0p BDT'), Binning(variable='shr_theta', bin_edges=array([0.        , 0.22435714, 0.44871429, 0.67307143, 0.89742857,
#        1.12178571, 1.34614286, 1.5705    , 1.79485714, 2.01921429,
#        2.24357143, 2.46792857, 2.69228571, 2.91664286, 3.141     ]), label='NPBDT_SHR_THETA', variable_tex='Reconstructed Shower $\\theta$', is_log=False, selection_query='nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_tracks_contained > 0 and nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_tracks_contained > 0 and CosmicIPAll3D > 10. and trkpid < 0.02 and hits_ratio > 0.50 and shrmoliereavg < 9 and subcluster > 4 and trkfit < 0.65 and tksh_distance < 6.0 and (shr_tkfit_nhits_tot > 1 and shr_tkfit_dedx_max > 0.5 and shr_tkfit_dedx_max < 5.5) and tksh_angle > -0.9 and shr_trk_len < 300. and pi0_score > 0.67 and nonpi0_score > 0.70 and n_showers_contained == 1', selection_key='NPBDT', preselection_key='NP', selection_tex='1eNp BDT sel.', selection_tex_short='1eNp BDT'), Binning(variable='shr_theta', bin_edges=array([0.        , 0.22435714, 0.44871429, 0.67307143, 0.89742857,
#        1.12178571, 1.34614286, 1.5705    , 1.79485714, 2.01921429,
#        2.24357143, 2.46792857, 2.69228571, 2.91664286, 3.141     ]), label='ZPBDT_SHR_THETA', variable_tex='Reconstructed Shower $\\theta$', is_log=False, selection_query='nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_tracks_contained == 0 and nslice == 1 and selected == 1 and shr_energy_tot_cali > 0.07 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and n_showers_contained == 1 and CosmicIPAll3D > 10. and CosmicDirAll3D > -0.9 and CosmicDirAll3D < 0.9 and shrmoliereavg < 15 and subcluster > 4 and trkfit < 0.65 and secondshower_Y_nhit < 50 and shr_trk_sce_start_y > -100 and shr_trk_sce_start_y < 80 and shr_trk_sce_end_y > -100 and shr_trk_sce_end_y < 100  and shr_trk_len < 300. and (n_tracks_tot == 0 or (n_tracks_tot>0 and tk1sh1_angle_alltk>-0.9)) and bkg_score > 0.72 and n_tracks_contained == 0 and (n_tracks_tot == 0 or (n_tracks_tot>0 and tk1sh1_angle_alltk>-0.9))', selection_key='ZPBDT', preselection_key='ZP', selection_tex='1e0p BDT sel.', selection_tex_short='1e0p BDT')], is_log=False), 'make_plots': True, 'enable_detvar_cache': True, 'show_plots': False, 'detvar_cache_dir': '/nashome/a/atrettin/PELEE/full_ana_output/detvar_cache', 'plot_output_dir': '/nashome/a/atrettin/PELEE/full_ana_output/detvar_plots'}
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Loading devar histograms from file: /nashome/a/atrettin/PELEE/full_ana_output/detvar_cache/run_1234b4c4d5_NPBDT_SHR_E_ZPBDT_SHR_E_NPBDT_SHR_THETA_ZPBDT_SHR_THETA_bnb_(mcf_pass_ncpi0_eqeq_1_or_(abs(nu_pdg)_eqeq_12_and_ccnc_eqeq_0)).json
# Making plots for mc
# Making plots for nue
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for nc_pi0
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for mc
# Making plots for nue
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for nc_pi0
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for mc
# Making plots for nue
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for nc_pi0
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Making plots for mc
# Making plots for nue
# Making plots for nc_pi0
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",

# %%
from plot_analysis_histograms_correlations import (
    print_error_budget_tables,
    print_constraint_error_reduction_table,
    plot_correlations,
    plot_constraint_update
)

# %%
print_error_budget_tables(analysis, "../full_ana_output/error_budget_tables.tex")

# show file content in output
with open("../full_ana_output/error_budget_tables.tex") as f:
    print(f.read())
# Out:
# Including detsim uncertainties
# Including detsim uncertainties
# Including detsim uncertainties
# \begin{table}
# \caption{Error budget for 1eNp BDT sel.}
# \begin{tabular}{lccccccc}
# \toprule
# Reconstructed Shower Energy (GeV) & GENIE & Flux & G4 & Detsys &\thead{GENIE \\+ Flux \\+ Reint \\+ Detsys} & Stat & Total $\sigma/\mu$\\
# \midrule
# 0.05 - 0.16 & 0.69 & 0.69 & 0.59 & 0.31 & 0.84 & 0.54 & 0.30 \\
# 0.16 - 0.26 & 0.60 & 0.36 & 0.18 & 0.65 & 0.94 & 0.35 & 0.18 \\
# 0.26 - 0.37 & 0.77 & 0.42 & 0.17 & 0.32 & 0.94 & 0.35 & 0.14 \\
# 0.37 - 0.48 & 0.81 & 0.51 & 0.28 & 0.22 & 0.95 & 0.31 & 0.15 \\
# 0.48 - 0.59 & 0.80 & 0.53 & 0.43 & 0.45 & 0.98 & 0.22 & 0.17 \\
# 0.59 - 0.69 & 0.82 & 0.61 & 0.48 & 0.36 & 0.97 & 0.23 & 0.16 \\
# 0.69 - 0.80 & 0.86 & 0.65 & 0.58 & 0.29 & 0.97 & 0.25 & 0.18 \\
# 0.80 - 0.91 & 0.80 & 0.56 & 0.46 & 0.48 & 0.99 & 0.16 & 0.18 \\
# 0.91 - 1.01 & 0.74 & 0.57 & 0.48 & 0.55 & 0.98 & 0.19 & 0.22 \\
# 1.01 - 1.12 & 0.71 & 0.50 & 0.38 & 0.58 & 0.97 & 0.23 & 0.21 \\
# 1.12 - 1.23 & 0.73 & 0.56 & 0.41 & 0.44 & 0.94 & 0.33 & 0.19 \\
# 1.23 - 1.34 & 0.59 & 0.50 & 0.34 & 0.69 & 0.98 & 0.18 & 0.23 \\
# 1.34 - 1.44 & 0.60 & 0.49 & 0.35 & 0.70 & 0.98 & 0.19 & 0.25 \\
# 1.44 - 1.55 & 0.66 & 0.57 & 0.44 & 0.60 & 0.97 & 0.23 & 0.25 \\
# \bottomrule
# \end{tabular}
# \end{table}
# \begin{table}
# \caption{Error budget for 1e0p BDT sel.}
# \begin{tabular}{lccccccc}
# \toprule
# Reconstructed Shower Energy (GeV) & GENIE & Flux & G4 & Detsys &\thead{GENIE \\+ Flux \\+ Reint \\+ Detsys} & Stat & Total $\sigma/\mu$\\
# \midrule
# 0.05 - 0.16 & 0.35 & 0.12 & 0.12 & 0.75 & 0.84 & 0.54 & 0.38 \\
# 0.16 - 0.26 & 0.59 & 0.26 & 0.14 & 0.56 & 0.85 & 0.53 & 0.25 \\
# 0.26 - 0.37 & 0.62 & 0.39 & 0.23 & 0.29 & 0.75 & 0.66 & 0.25 \\
# 0.37 - 0.48 & 0.48 & 0.35 & 0.29 & 0.67 & 0.85 & 0.53 & 0.31 \\
# 0.48 - 0.59 & 0.71 & 0.62 & 0.55 & 0.27 & 0.82 & 0.57 & 0.24 \\
# 0.59 - 0.69 & 0.47 & 0.35 & 0.32 & 0.56 & 0.74 & 0.67 & 0.31 \\
# 0.69 - 0.80 & 0.62 & 0.47 & 0.43 & 0.47 & 0.81 & 0.59 & 0.27 \\
# 0.80 - 0.91 & 0.62 & 0.46 & 0.39 & 0.67 & 0.95 & 0.32 & 0.29 \\
# 0.91 - 1.01 & 0.71 & 0.50 & 0.42 & 0.60 & 0.97 & 0.23 & 0.27 \\
# 1.01 - 1.12 & 0.58 & 0.39 & 0.31 & 0.59 & 0.86 & 0.51 & 0.35 \\
# 1.12 - 1.23 & 0.39 & 0.33 & 0.27 & 0.36 & 0.56 & 0.83 & 0.37 \\
# 1.23 - 1.34 & 0.66 & 0.57 & 0.47 & 0.62 & 0.96 & 0.28 & 0.31 \\
# 1.34 - 1.44 & 0.52 & 0.45 & 0.39 & 0.77 & 0.96 & 0.29 & 0.49 \\
# 1.44 - 1.55 & 0.36 & 0.32 & 0.25 & 0.89 & 0.98 & 0.19 & 0.55 \\
# \bottomrule
# \end{tabular}
# \end{table}
# \begin{table}
# \caption{Error budget for $1\mu$Np0$\pi$ selection w/ CRT}
# \begin{tabular}{lccccccc}
# \toprule
# Neutrino Reconstructed Energy (GeV) & GENIE & Flux & G4 & Detsys &\thead{GENIE \\+ Flux \\+ Reint \\+ Detsys} & Stat & Total $\sigma/\mu$\\
# \midrule
# 0.15 - 0.25 & 0.44 & 0.35 & 0.25 & 0.77 & 0.92 & 0.38 & 0.35 \\
# 0.25 - 0.35 & 0.76 & 0.70 & 0.41 & 0.22 & 0.98 & 0.17 & 0.17 \\
# 0.35 - 0.45 & 0.80 & 0.59 & 0.28 & 0.24 & 0.99 & 0.12 & 0.14 \\
# 0.45 - 0.55 & 0.83 & 0.50 & 0.20 & 0.24 & 0.99 & 0.11 & 0.14 \\
# 0.55 - 0.65 & 0.83 & 0.42 & 0.17 & 0.36 & 0.99 & 0.11 & 0.14 \\
# 0.65 - 0.75 & 0.83 & 0.42 & 0.11 & 0.37 & 0.99 & 0.12 & 0.14 \\
# 0.75 - 0.85 & 0.85 & 0.44 & 0.20 & 0.29 & 0.99 & 0.14 & 0.15 \\
# 0.85 - 0.95 & 0.88 & 0.50 & 0.33 & 0.20 & 0.99 & 0.15 & 0.16 \\
# 0.95 - 1.05 & 0.81 & 0.47 & 0.25 & 0.38 & 0.99 & 0.16 & 0.17 \\
# 1.05 - 1.15 & 0.78 & 0.54 & 0.31 & 0.36 & 0.98 & 0.17 & 0.19 \\
# 1.15 - 1.25 & 0.77 & 0.60 & 0.32 & 0.28 & 0.98 & 0.20 & 0.19 \\
# 1.25 - 1.35 & 0.67 & 0.54 & 0.25 & 0.52 & 0.98 & 0.20 & 0.23 \\
# 1.35 - 1.45 & 0.73 & 0.67 & 0.46 & 0.40 & 0.97 & 0.23 & 0.25 \\
# 1.45 - 1.55 & 0.62 & 0.60 & 0.17 & 0.43 & 0.95 & 0.30 & 0.23 \\
# \bottomrule
# \end{tabular}
# \end{table}
# \begin{table}
# \caption{Error budget for $1\mu$0p0$\pi$ selection w/ CRT}
# \begin{tabular}{lccccccc}
# \toprule
# Neutrino Reconstructed Energy (GeV) & GENIE & Flux & G4 & Detsys &\thead{GENIE \\+ Flux \\+ Reint \\+ Detsys} & Stat & Total $\sigma/\mu$\\
# \midrule
# 0.15 - 0.25 & 0.70 & 0.73 & 0.49 & 0.40 & 0.98 & 0.20 & 0.20 \\
# 0.25 - 0.35 & 0.78 & 0.65 & 0.51 & 0.43 & 0.99 & 0.14 & 0.17 \\
# 0.35 - 0.45 & 0.79 & 0.62 & 0.51 & 0.47 & 0.99 & 0.13 & 0.16 \\
# 0.45 - 0.55 & 0.80 & 0.59 & 0.48 & 0.46 & 0.99 & 0.14 & 0.15 \\
# 0.55 - 0.65 & 0.85 & 0.66 & 0.57 & 0.36 & 0.99 & 0.14 & 0.16 \\
# 0.65 - 0.75 & 0.76 & 0.56 & 0.46 & 0.53 & 0.99 & 0.14 & 0.17 \\
# 0.75 - 0.85 & 0.79 & 0.59 & 0.44 & 0.44 & 0.99 & 0.17 & 0.16 \\
# 0.85 - 0.95 & 0.74 & 0.59 & 0.49 & 0.57 & 0.99 & 0.14 & 0.18 \\
# 0.95 - 1.05 & 0.79 & 0.64 & 0.45 & 0.35 & 0.98 & 0.20 & 0.17 \\
# 1.05 - 1.15 & 0.70 & 0.60 & 0.39 & 0.50 & 0.98 & 0.20 & 0.19 \\
# 1.15 - 1.25 & 0.67 & 0.68 & 0.48 & 0.53 & 0.98 & 0.20 & 0.21 \\
# 1.25 - 1.35 & 0.65 & 0.62 & 0.39 & 0.54 & 0.97 & 0.25 & 0.22 \\
# 1.35 - 1.45 & 0.67 & 0.72 & 0.44 & 0.39 & 0.96 & 0.27 & 0.22 \\
# 1.45 - 1.55 & 0.56 & 0.64 & 0.39 & 0.59 & 0.96 & 0.27 & 0.26 \\
# \bottomrule
# \end{tabular}
# \end{table}
# \begin{table}
# \caption{Error budget for 1e0p loose sel. 2+ shr}
# \begin{tabular}{lccccccc}
# \toprule
# Neutrino Reconstructed Energy (GeV) & GENIE & Flux & G4 & Detsys &\thead{GENIE \\+ Flux \\+ Reint \\+ Detsys} & Stat & Total $\sigma/\mu$\\
# \midrule
# 0.15 - 0.23 & 0.74 & 0.29 & 0.10 & 0.56 & 0.96 & 0.27 & 0.20 \\
# 0.23 - 0.32 & 0.78 & 0.33 & 0.07 & 0.47 & 0.97 & 0.24 & 0.21 \\
# 0.32 - 0.41 & 0.84 & 0.30 & 0.10 & 0.40 & 0.97 & 0.23 & 0.22 \\
# 0.41 - 0.49 & 0.82 & 0.35 & 0.05 & 0.36 & 0.96 & 0.26 & 0.23 \\
# 0.49 - 0.57 & 0.68 & 0.31 & 0.06 & 0.62 & 0.97 & 0.24 & 0.29 \\
# 0.57 - 0.66 & 0.48 & 0.23 & 0.03 & 0.83 & 0.98 & 0.19 & 0.48 \\
# 0.66 - 0.74 & 0.62 & 0.26 & 0.06 & 0.68 & 0.96 & 0.29 & 0.37 \\
# 0.74 - 0.83 & 0.42 & 0.25 & 0.05 & 0.84 & 0.97 & 0.24 & 0.54 \\
# 0.83 - 0.91 & 0.37 & 0.29 & 0.08 & 0.81 & 0.94 & 0.34 & 0.50 \\
# 0.91 - 1.00 & 0.44 & 0.22 & 0.06 & 0.79 & 0.93 & 0.36 & 0.52 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
plot_constraint_update(analysis, "../full_ana_output/")
# Out:
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Including detsim uncertainties
# Including detsim uncertainties
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",

# %%
print_constraint_error_reduction_table(analysis, "../full_ana_output/constraint_error_reduction_table_shr_ang.tex")

# show file content in output
with open("../full_ana_output/constraint_error_reduction_table_shr_ang.tex") as f:
    print(f.read())
# Out:
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Including detsim uncertainties
# Including detsim uncertainties
# \begin{table}
# \caption{Error reduction due to constraints for 1eNp BDT sel.}
# \begin{tabular}{lccc}
# \toprule
# Reconstructed Shower $\theta$ & Error before constraint & Error after constraint & Reduction \\
# \midrule
# 0.00 - 0.22 & 23.0\% & 15.8\% & 31.1\% \\
# 0.22 - 0.45 & 20.7\% & 12.5\% & 39.7\% \\
# 0.45 - 0.67 & 15.8\% & 7.0\% & 55.7\% \\
# 0.67 - 0.90 & 14.1\% & 6.8\% & 51.9\% \\
# 0.90 - 1.12 & 14.1\% & 7.1\% & 49.7\% \\
# 1.12 - 1.35 & 16.6\% & 8.6\% & 48.0\% \\
# 1.35 - 1.57 & 27.4\% & 9.8\% & 64.0\% \\
# 1.57 - 1.79 & 22.6\% & 15.5\% & 31.3\% \\
# 1.79 - 2.02 & 42.8\% & 14.1\% & 67.1\% \\
# 2.02 - 2.24 & 24.1\% & 15.1\% & 37.2\% \\
# 2.24 - 2.47 & 44.9\% & 24.5\% & 45.3\% \\
# 2.47 - 2.69 & 59.2\% & 35.8\% & 39.4\% \\
# 2.69 - 2.92 & 133.6\% & 148.4\% & -11.1\% \\
# 2.92 - 3.14 & 1049.2\% & -347.0\% & 133.1\% \\
# \bottomrule
# \end{tabular}
# \end{table}
# \begin{table}
# \caption{Error reduction due to constraints for 1e0p BDT sel.}
# \begin{tabular}{lccc}
# \toprule
# Reconstructed Shower $\theta$ & Error before constraint & Error after constraint & Reduction \\
# \midrule
# 0.00 - 0.22 & 23.5\% & 14.0\% & 40.3\% \\
# 0.22 - 0.45 & 22.5\% & 11.7\% & 48.1\% \\
# 0.45 - 0.67 & 34.2\% & 17.9\% & 47.5\% \\
# 0.67 - 0.90 & 25.8\% & 17.5\% & 32.2\% \\
# 0.90 - 1.12 & 34.2\% & 24.7\% & 27.6\% \\
# 1.12 - 1.35 & 36.6\% & 23.3\% & 36.3\% \\
# 1.35 - 1.57 & 32.7\% & 27.6\% & 15.5\% \\
# 1.57 - 1.79 & 74.9\% & 69.9\% & 6.7\% \\
# 1.79 - 2.02 & 82.7\% & 91.0\% & -9.9\% \\
# 2.02 - 2.24 & 82.9\% & 66.2\% & 20.1\% \\
# 2.24 - 2.47 & 80.8\% & 52.8\% & 34.7\% \\
# 2.47 - 2.69 & 113.5\% & 106.9\% & 5.8\% \\
# 2.69 - 2.92 & 156.5\% & 149.1\% & 4.7\% \\
# 2.92 - 3.14 & 81.2\% & 75.2\% & 7.4\% \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
# analysis.signal_channels = ["NPBDT_SHR_THETA", "ZPBDT_SHR_THETA"]
analysis.plot_signals(
    separate_figures=True,
    save_path="../full_ana_output/",
)
# Out:
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",

# %%
analysis.parameters["signal_strength"].value = 0.0

multi_channel_hist_unconstrained = analysis.generate_multiband_histogram(
    include_multisim_errors=True, use_sideband=False,
)

multi_channel_hist_new_constraints = analysis.generate_multiband_histogram(
    include_multisim_errors=True, use_sideband=True,
    constraint_channels=["NUMUCRTNP0PI", "NUMUCRT0P0PI", "TWOSHR"],
)

multi_channel_hist_old_constraints = analysis.generate_multiband_histogram(
    include_multisim_errors=True, use_sideband=True,
    constraint_channels=["NUMUCRT"],
)
# Out:
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 4.5), constrained_layout=True, nrows=2, gridspec_kw={"height_ratios": [3, 1]}, sharex=True)
multi_channel_hist_unconstrained.draw(ax=ax[0], label="Unconstrained", color="black")
multi_channel_hist_old_constraints.draw(ax=ax[0], label="NUMU Constraint")
multi_channel_hist_new_constraints.draw(ax=ax[0], label="New Constraints w/ CRT")

rel_error_unconstr = multi_channel_hist_unconstrained / multi_channel_hist_unconstrained.bin_counts
rel_error_unconstr.draw(ax=ax[1], color="k", show_channel_labels=False)

rel_error_old = multi_channel_hist_old_constraints / multi_channel_hist_old_constraints.bin_counts
rel_error_old.draw(ax=ax[1], show_channel_labels=False)

rel_error_new = multi_channel_hist_new_constraints / multi_channel_hist_new_constraints.bin_counts
rel_error_new.draw(ax=ax[1], show_channel_labels=False)
ax[0].set_xlabel("")
ax[1].set_xlabel("Global bin number")
ax[1].set_ylabel("Rel. error")
ax[0].legend()
ax[0].set_title("Signal Channels, Runs 1-5, MC+EXT, Shower Angle")
fig.savefig("../full_ana_output/new_vs_old_constraint_comparison_shr_angle.pdf")

# %%
from microfit.parameters import ParameterSet, Parameter
from microfit.fileio import to_json

analysis.constraint_channels = ["NUMUCRTNP0PI", "NUMUCRT0P0PI", "TWOSHR"]
analysis.signal_channels = ["NPBDT_SHR_E", "ZPBDT_SHR_E"]

two_hypo_result_new_constraints = analysis.two_hypothesis_test(
    h0_params=ParameterSet([Parameter("signal_strength", 0.0)]),
    h1_params=ParameterSet([Parameter("signal_strength", 1.0)]),
    sensitivity_only=True,
    n_trials=100000,
)

to_json("../full_ana_output/two_hypo_result_new_constraints.json", two_hypo_result_new_constraints)
# Out:
# Generating H0 histogram
# Including detsim uncertainties
# Generating H1 histogram
# Including detsim uncertainties
# Generating pseudo-experiments: 100%|██████████| 100000/100000 [09:01<00:00, 184.66it/s]

# %%
from microfit.fileio import from_json
import matplotlib.pyplot as plt

# read results from file
two_hypo_results = from_json(os.path.join("../full_ana_output", "two_hypo_result_new_constraints.json"))
minimum = np.min(two_hypo_results["samples_h0"])
minimum = min(minimum, np.min(two_hypo_results["samples_h1"]))
maximum = np.max(two_hypo_results["samples_h0"])
maximum = max(maximum, np.max(two_hypo_results["samples_h1"]))

bin_edges = np.linspace(minimum, maximum, int(np.sqrt(n_trials)))

n_trials = len(two_hypo_results["samples_h0"])
fig, ax = plt.subplots(figsize=(5, 4), constrained_layout=True)
ax.hist(two_hypo_results["samples_h0"], bins=bin_edges, histtype="step", density=True, label="H0")
ax.hist(two_hypo_results["samples_h1"], bins=bin_edges, histtype="step", density=True, label="H1")
ax.axvline(x=two_hypo_results["ts_median_h1"], color="k", linestyle="--", label=f"Median H1\np-val: {two_hypo_results['median_pval']*100:0.3f}%")
ax.legend()
ax.set_xlabel(r"$\Delta \chi^2$")
ax.set_ylabel("Probability density")
ax.set_title("Sensitivity, Runs 1-5, Reco. Shower Energy")
fig.savefig(os.path.join("../full_ana_output", "two_hypo_result_new_constraints.pdf"))

# %%
from microfit.parameters import ParameterSet, Parameter
from microfit.fileio import to_json

analysis.constraint_channels = ["NUMUCRTNP0PI", "NUMUCRT0P0PI", "TWOSHR"]
analysis.signal_channels = ["NPBDT_SHR_THETA", "ZPBDT_SHR_THETA"]

two_hypo_result_new_constraints_shr_theta = analysis.two_hypothesis_test(
    h0_params=ParameterSet([Parameter("signal_strength", 0.0)]),
    h1_params=ParameterSet([Parameter("signal_strength", 1.0)]),
    sensitivity_only=True,
    n_trials=100000,
)

to_json("../full_ana_output/two_hypo_result_new_constraints_shr_theta.json", two_hypo_result_new_constraints_shr_theta)
# Out:
# Generating H0 histogram
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Including detsim uncertainties
# Generating H1 histogram
# Including detsim uncertainties
# Generating pseudo-experiments: 100%|██████████| 100000/100000 [09:12<00:00, 180.98it/s]

# %%
from microfit.fileio import from_json
import matplotlib.pyplot as plt

# read results from file
two_hypo_results = from_json(os.path.join("../full_ana_output", "two_hypo_result_new_constraints_shr_theta.json"))
minimum = np.min(two_hypo_results["samples_h0"])
minimum = min(minimum, np.min(two_hypo_results["samples_h1"]))
maximum = np.max(two_hypo_results["samples_h0"])
maximum = max(maximum, np.max(two_hypo_results["samples_h1"]))

minimum = -80
bin_edges = np.linspace(minimum, maximum, int(np.sqrt(n_trials)))

n_trials = len(two_hypo_results["samples_h0"])
fig, ax = plt.subplots(figsize=(5, 4), constrained_layout=True)
ax.hist(two_hypo_results["samples_h0"], bins=bin_edges, histtype="step", density=True, label="H0")
ax.hist(two_hypo_results["samples_h1"], bins=bin_edges, histtype="step", density=True, label="H1")
ax.axvline(x=two_hypo_results["ts_median_h1"], color="k", linestyle="--", label=f"Median H1\np-val: {two_hypo_results['median_pval']*100:0.3f}%")
ax.legend()
ax.set_xlabel(r"$\Delta \chi^2$")
ax.set_ylabel("Probability density")
ax.set_title("Sensitivity, Runs 1-5, Reco. Shower Angle")
fig.savefig(os.path.join("../full_ana_output", "two_hypo_result_new_constraints_shr_theta.pdf"))

# %%
from microfit.parameters import ParameterSet, Parameter
from microfit.fileio import to_json

analysis.constraint_channels = ["NUMUCRTNP0PI", "NUMUCRT0P0PI", "TWOSHR"]
analysis.signal_channels = ["NPBDT_SHR_THETA", "ZPBDT_SHR_THETA"]

two_hypo_result_new_constraints_shr_theta = analysis.two_hypothesis_test(
    h0_params=ParameterSet([Parameter("signal_strength", 0.0)]),
    h1_params=ParameterSet([Parameter("signal_strength", 1.0)]),
    sensitivity_only=True,
    n_trials=10000,
    add_precomputed_detsys=True
)

to_json("../full_ana_output/two_hypo_result_new_constraints_shr_theta_with_detvar.json", two_hypo_result_new_constraints_shr_theta)
# Out:
# Generating H0 histogram
# ../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Including detsim uncertainties
# Generating H1 histogram
# Including detsim uncertainties
# Generating pseudo-experiments: 100%|██████████| 10000/10000 [01:04<00:00, 154.16it/s]

# %%
from microfit.fileio import from_json
import matplotlib.pyplot as plt

# read results from file
two_hypo_results = from_json(os.path.join("../full_ana_output", "two_hypo_result_new_constraints_shr_theta_with_detvar.json"))
minimum = np.min(two_hypo_results["samples_h0"])
minimum = min(minimum, np.min(two_hypo_results["samples_h1"]))
maximum = np.max(two_hypo_results["samples_h0"])
maximum = max(maximum, np.max(two_hypo_results["samples_h1"]))

# minimum = -80
bin_edges = np.linspace(minimum, maximum, int(np.sqrt(n_trials)))

n_trials = len(two_hypo_results["samples_h0"])
fig, ax = plt.subplots(figsize=(5, 4), constrained_layout=True)
ax.hist(two_hypo_results["samples_h0"], bins=bin_edges, histtype="step", density=True, label="H0")
ax.hist(two_hypo_results["samples_h1"], bins=bin_edges, histtype="step", density=True, label="H1")
ax.axvline(x=two_hypo_results["ts_median_h1"], color="k", linestyle="--", label=f"Median H1\np-val: {two_hypo_results['median_pval']*100:0.3f}%")
ax.legend()
ax.set_xlabel(r"$\Delta \chi^2$")
ax.set_ylabel("Probability density")
ax.set_title("Sensitivity, Runs 1-5, Reco. Shower Angle")
# Out:
# Text(0.5, 1.0, 'Sensitivity, Runs 1-5, Reco. Shower Angle')

# %%
import numpy as np

analysis.constraint_channels = ["NUMUCRTNP0PI", "NUMUCRT0P0PI", "TWOSHR"]
analysis.signal_channels = ["NPBDT_SHR_E", "ZPBDT_SHR_E"]

scan_points = np.linspace(0, 5, 40)
fit_grid = {
    "signal_strength": np.linspace(0, 10, 50),
}
fc_scan_results = analysis.scan_asimov_fc_sensitivity(
    scan_points=scan_points,
    parameter_name="signal_strength",
    n_trials=1000,
    fit_method="grid_scan",
    fit_grid=fit_grid,
)
# Out:
# Running FC scan over 40 points in signal_strength...
# Scanning:   0%|          | 0/40 [00:00<?, ?it/s]../microfit/histogram/binning.py:265: UserWarning: The 'labels' property is deprecated. Use 'channels' instead.
#   "The 'labels' property is deprecated. Use 'channels' instead.",
# Scanning: 100%|██████████| 40/40 [37:30<00:00, 56.25s/it]
# Calculating Asimov sensitivity for 40 points...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 5))

MultibandAnalysis.plot_fc_scan_results(
    fc_scan_results,
    parameter_tex="signal strength",
    ax=ax,
)
ax.set_xlim((0, 5))
ax.set_ylim((0, 5))

ax.set_title("Runs 1-5, New Signal Model")
fig.savefig("runs1-5_fc_scan_new_constraints_new_signal.pdf")
