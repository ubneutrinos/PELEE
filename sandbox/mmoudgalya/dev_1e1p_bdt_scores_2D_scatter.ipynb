# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append("../../")
import data_loading as dl
from importlib import reload
reload(dl)

from microfit import run_plotter as rp
from microfit import histogram as hist

from microfit import variable_definitions as vdef
from microfit import selections

# %%
keep_vars = [
    "Signal_1e1p", "mc_signal_1e1p", "nu_pdg", "TrueElecIdx", "TrueLeadProtonIdx", "InFV", "HasNoMesons",
    "TrueNElec", "TrueNProt", "TrueDeltaPT", "TrueDeltaAlphaT", "TruePN", "TrueAlpha3D",
    "nproton", "npion", "npi0", "nelec", "nmuon", "isVtxInFiducial",
    "Sel_1e1p", "sel_1e1p_w_cuts", "RecoElectronCandidateIdx", "RecoLeadProtonCandidateIdx", "InFV_reco",
    "RecoElecPassMomCut", "RecoLeadProtonPassMomCut", "n_reco_tracks", "n_reco_showers",
    "RecoDeltaPT", "RecoDeltaAlphaT", "RecoPN", "RecoAlpha3D", "RecoECal", "Reco_mag_q", "RecoPL",
    "nslice", "selected", "shr_energy_tot_cali", "_opfilter_pe_beam", "_opfilter_pe_veto", "bnbdata", "extdata",
    "CosmicIPAll3D", "hits_ratio", "shrmoliereavg", "subcluster", "trkfit", "trkshrhitdist2", "tksh_distance",
    "shr_tkfit_nhits_tot", "shr_tkfit_dedx_max", "tksh_angle", "shr_trk_len", "reco_e",
    "RecoLeadProton_trk_len", "RecoLeadProton_trk_trunk_dEdx_y", "RecoLeadProton_dEdx_y_per_trklen",
    "RecoLeadProtonCandidate_trk_pid", "RecoElectronCandidate_shr_pid", "RecoElectron_conversion_dist",
    "pi0_radlen1", "pi0_radlen2", "pi0_score", "nonpi0_score", "bkg_score",
    "RecoElecE", "RecoElecModMom", "RecoElecMomX", "RecoElecMomY", "RecoElecMomZ",
    "RecoLeadProtonKE", "RecoLeadProtonModMom", "RecoLeadProtonMomX", "RecoLeadProtonMomY", "RecoLeadProtonMomZ",
]

# %%
#RUN = ["1","2","3","4b","4c","4d","5"]
RUN = ["3"]

rundata, mc_weights, data_pot = dl.load_runs(
    RUN,
    data="bnb",
    loadpi0variables=False,
    loadshowervariables=True,
    loadrecoveryvars=False,
    loadsystematics=True,
    numupresel=False,
    loadnumuvariables=False,
    use_bdt=True,
    load_lee=False,
    load_nue_tki=True,
    keep_columns=keep_vars,
    blinded=True,
    load_crt_vars=False,
    enable_cache=False,
)
# Out:
# Loading run 3
# Updating keep_columns with truth-filtering variables: {'ccnc', 'nu_pdg'}
# /exp/uboone/data/users/cthorpe/PELEE_2023_Samples/run3/nuepresel/bnb_beam_off_peleeTuple_uboone_v08_00_00_70_run3.root
# Calc true TKI variables for leading proton only
# Calc true GKI variables for leading proton only
# Calc reco TKI variables for leading proton only
# Calc reco GKI variables for leading proton only
# /exp/uboone/data/users/cthorpe/PELEE_2023_Samples/run3/nuepresel/overlay_peleeTuple_uboone_v08_00_00_70_run3_nu.root
# ../../data_loading.py:857: RuntimeWarning: invalid value encountered in true_divide
#   df["proton_pz"] = np.where((mc_E_prot > 0), mc_pz_prot / mc_p_prot, np.nan)
# Calc true TKI variables for leading proton only
# Calc true GKI variables for leading proton only
# Calc reco TKI variables for leading proton only
# Calc reco GKI variables for leading proton only
# /exp/uboone/data/users/cthorpe/PELEE_2023_Samples/run3/nuepresel/overlay_peleeTuple_uboone_v08_00_00_70_run3_nue.root
# Calc true TKI variables for leading proton only
# Calc true GKI variables for leading proton only
# Calc reco TKI variables for leading proton only
# Calc reco GKI variables for leading proton only
# /exp/uboone/data/users/cthorpe/PELEE_2023_Samples/run3/nuepresel/overlay_peleeTuple_uboone_v08_00_00_70_run3_dirt.root
# Calc true TKI variables for leading proton only
# Calc true GKI variables for leading proton only
# Calc reco TKI variables for leading proton only
# Calc reco GKI variables for leading proton only

# %%
run_combo = "Run"
for run in RUN:
    run_combo += run

# %%
from microfit import selections as sel

selection = "None"
preselection = "OneP_new"
query = f"{sel.preselection_categories[preselection]['query']}" #" and {sel.selection_categories[selection]['query']}"
#sel_title = f"{sel.selection_categories[selection]['title']}"

all_mc = pd.concat([df for k, df in rundata.items() if k!='data'])
sel_mc = all_mc.query(query, engine='python')
is_sig = sel_mc['category_1e1p'] == 12
sel_sig = sel_mc.loc[is_sig]
sel_bkg = sel_mc.loc[~is_sig]

# %%
# Selected signal - pi0 & non-pi0

plt.plot(sel_sig["pi0_score"], sel_sig["nonpi0_score"], "+", color="tab:green")
plt.xlabel('BDT $\\pi^{0}$ score')
plt.ylabel('BDT non-$\\pi^{0}$ score')  
plt.title(f"Selected Signal Events")
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_sig_pi0score_nonpi0score_{preselection}_{selection}_{run_combo}.pdf', bbox_inches='tight')
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_sig_pi0score_nonpi0score_{preselection}_{selection}_{run_combo}.png', bbox_inches='tight')
plt.show()
plt.clf()

# %%
# Selected signal - pi0 & 0p

plt.plot(sel_sig["pi0_score"], sel_sig["bkg_score"], "+", color="tab:green")
plt.xlabel('BDT $\\pi^{0}$ score')
plt.ylabel('1e0p BDT score')  
plt.title(f"Selected Signal Events")
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_sig_pi0score_0pscore_{preselection}_{selection}_{run_combo}.pdf', bbox_inches='tight')
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_sig_pi0score_0pscore_{preselection}_{selection}_{run_combo}.png', bbox_inches='tight')
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_2358025/267333699.py in <module>
#       9
#      10 plt.title(f"Selected Signal Events")
# ---> 11 plt.savefig(f'plots/reco_study/conversion_dedx/2Dplots_sig_conversion_dedx_{preselection}_{selection}_{run_combo}.pdf', bbox_inches='tight')
#      12 plt.savefig(f'plots/reco_study/conversion_dedx/2Dplots_sig_conversion_dedx_{selection}_{run_combo}.png', bbox_inches='tight')
#      13 plt.show()
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     975 def savefig(*args, **kwargs):
#     976     fig = gcf()
# --> 977     res = fig.savefig(*args, **kwargs)
#     978     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     979     return res
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3056                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3057
# -> 3058             self.canvas.print_figure(fname, **kwargs)
#    3059
#    3060     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2257
#    2258         # get canvas object and print method for format
# -> 2259         canvas = self._get_output_canvas(backend, format)
#    2260         print_method = getattr(canvas, 'print_%s' % format)
#    2261
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backend_bases.py in _get_output_canvas(self, backend, fmt)
#    2182         else:
#    2183             # Return a default canvas for the requested format, if it exists.
# -> 2184             canvas_class = get_registered_canvas_class(fmt)
#    2185         if canvas_class:
#    2186             return self.switch_backends(canvas_class)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backend_bases.py in get_registered_canvas_class(format)
#     142     backend_class = _default_backends[format]
#     143     if isinstance(backend_class, str):
# --> 144         backend_class = importlib.import_module(backend_class).FigureCanvas
#     145         _default_backends[format] = backend_class
#     146     return backend_class
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py in <module>
#      45 from matplotlib.dates import UTC
#      46 from matplotlib import _path
# ---> 47 from . import _backend_pdf_ps
#      48
#      49 _log = logging.getLogger(__name__)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backends/_backend_pdf_ps.py in <module>
#       6 import functools
#       7
# ----> 8 from fontTools import subset
#       9
#      10 import matplotlib as mpl
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/fontTools/subset/__init__.py in <module>
#       6 from fontTools.misc.roundTools import otRound
#       7 from fontTools import ttLib
# ----> 8 from fontTools.ttLib.tables import otTables
#       9 from fontTools.ttLib.tables.otBase import USE_HARFBUZZ_REPACKER
#      10 from fontTools.otlLib.maxContextCalc import maxCtxFont
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/fontTools/ttLib/tables/otTables.py in <module>
#      12 from fontTools.misc.roundTools import otRound
#      13 from fontTools.misc.textTools import bytesjoin, pad, safeEval
# ---> 14 from .otBase import (
#      15         BaseTable, FormatSwitchingBaseTable, ValueRecord, CountReference,
#      16         getFormatSwitchingBaseTableClass,
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/fontTools/ttLib/tables/otBase.py in <module>
#      14 have_uharfbuzz = False
#      15 try:
# ---> 16         import uharfbuzz as hb
#      17         # repack method added in uharfbuzz >= 0.23; if uharfbuzz *can* be
#      18         # imported but repack method is missing, behave as if uharfbuzz
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_spec(name, path, target)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in _get_spec(cls, fullname, path, target)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in find_spec(self, fullname, target)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in _fill_cache(self)
#
# OSError: [Errno 127] Key has expired: '/nashome/m/mmoudgal/.ipython'

# %%
# Selected signal - nonpi0 & 0p

plt.plot(sel_sig["nonpi0_score"], sel_sig["bkg_score"], "+", color="tab:green")
plt.xlabel('BDT non-$\\pi^{0}$ score')
plt.ylabel('1e0p BDT score')
plt.title(f"Selected Signal Events")
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_sig_nonpi0score_0pscore_{preselection}_{selection}_{run_combo}.pdf', bbox_inches='tight')
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_sig_nonpi0score_0pscore_{preselection}_{selection}_{run_combo}.png', bbox_inches='tight')
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_2358025/267333699.py in <module>
#       9
#      10 plt.title(f"Selected Signal Events")
# ---> 11 plt.savefig(f'plots/reco_study/conversion_dedx/2Dplots_sig_conversion_dedx_{preselection}_{selection}_{run_combo}.pdf', bbox_inches='tight')
#      12 plt.savefig(f'plots/reco_study/conversion_dedx/2Dplots_sig_conversion_dedx_{selection}_{run_combo}.png', bbox_inches='tight')
#      13 plt.show()
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     975 def savefig(*args, **kwargs):
#     976     fig = gcf()
# --> 977     res = fig.savefig(*args, **kwargs)
#     978     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     979     return res
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3056                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3057
# -> 3058             self.canvas.print_figure(fname, **kwargs)
#    3059
#    3060     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2257
#    2258         # get canvas object and print method for format
# -> 2259         canvas = self._get_output_canvas(backend, format)
#    2260         print_method = getattr(canvas, 'print_%s' % format)
#    2261
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backend_bases.py in _get_output_canvas(self, backend, fmt)
#    2182         else:
#    2183             # Return a default canvas for the requested format, if it exists.
# -> 2184             canvas_class = get_registered_canvas_class(fmt)
#    2185         if canvas_class:
#    2186             return self.switch_backends(canvas_class)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backend_bases.py in get_registered_canvas_class(format)
#     142     backend_class = _default_backends[format]
#     143     if isinstance(backend_class, str):
# --> 144         backend_class = importlib.import_module(backend_class).FigureCanvas
#     145         _default_backends[format] = backend_class
#     146     return backend_class
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py in <module>
#      45 from matplotlib.dates import UTC
#      46 from matplotlib import _path
# ---> 47 from . import _backend_pdf_ps
#      48
#      49 _log = logging.getLogger(__name__)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/matplotlib/backends/_backend_pdf_ps.py in <module>
#       6 import functools
#       7
# ----> 8 from fontTools import subset
#       9
#      10 import matplotlib as mpl
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/fontTools/subset/__init__.py in <module>
#       6 from fontTools.misc.roundTools import otRound
#       7 from fontTools import ttLib
# ----> 8 from fontTools.ttLib.tables import otTables
#       9 from fontTools.ttLib.tables.otBase import USE_HARFBUZZ_REPACKER
#      10 from fontTools.otlLib.maxContextCalc import maxCtxFont
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/fontTools/ttLib/tables/otTables.py in <module>
#      12 from fontTools.misc.roundTools import otRound
#      13 from fontTools.misc.textTools import bytesjoin, pad, safeEval
# ---> 14 from .otBase import (
#      15         BaseTable, FormatSwitchingBaseTable, ValueRecord, CountReference,
#      16         getFormatSwitchingBaseTableClass,
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/site-packages/fontTools/ttLib/tables/otBase.py in <module>
#      14 have_uharfbuzz = False
#      15 try:
# ---> 16         import uharfbuzz as hb
#      17         # repack method added in uharfbuzz >= 0.23; if uharfbuzz *can* be
#      18         # imported but repack method is missing, behave as if uharfbuzz
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap.py in _find_spec(name, path, target)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in _get_spec(cls, fullname, path, target)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in find_spec(self, fullname, target)
#
# /exp/uboone/app/users/mmoudgal/miniforge3/envs/python3LEE/lib/python3.7/importlib/_bootstrap_external.py in _fill_cache(self)
#
# OSError: [Errno 127] Key has expired: '/nashome/m/mmoudgal/.ipython'

# %%
# Selected background - pi0 & non-pi0

plt.plot(sel_bkg["pi0_score"], sel_bkg["nonpi0_score"], "+")
plt.xlabel('BDT $\\pi^{0}$ score')
plt.ylabel('BDT non-$\\pi^{0}$ score')
plt.title(f"Selected Background Events")
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_bkg_pi0score_nonpi0score_{preselection}_{selection}_{run_combo}.pdf', bbox_inches='tight')
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_bkg_pi0score_nonpi0score_{preselection}_{selection}_{run_combo}.png', bbox_inches='tight')
plt.show()
plt.clf()

# %%
# Selected background - pi0 & 0p

plt.plot(sel_bkg["pi0_score"], sel_bkg["bkg_score"], "+")
plt.xlabel('BDT $\\pi^{0}$ score')
plt.ylabel('1e0p BDT score')
plt.title(f"Selected Background Events")
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_bkg_pi0score_0pscore_{preselection}_{selection}_{run_combo}.pdf', bbox_inches='tight')
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_bkg_pi0score_0pscore_{preselection}_{selection}_{run_combo}.png', bbox_inches='tight')
plt.show()
plt.clf()

# %%
# Selected background - nonpi0 & 0p

plt.plot(sel_bkg["nonpi0_score"], sel_bkg["bkg_score"], "+")
plt.xlabel('BDT non-$\\pi^{0}$ score')
plt.ylabel('1e0p BDT score')
plt.title(f"Selected Background Events")
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_bkg_nonpi0score_0pscore_{preselection}_{selection}_{run_combo}.pdf', bbox_inches='tight')
plt.savefig(f'plots/reco_study/bdt_scores/2D_scatter_bkg_nonpi0score_0pscore_{preselection}_{selection}_{run_combo}.png', bbox_inches='tight')
plt.show()
plt.clf()
