# %% [markdown]
# ###### Always include the first 2 cells below in any program + any additional add-ons

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append("../../")
from data_loading import load_runs
import data_loading as dl
from importlib import reload
reload(dl)

from microfit import run_plotter as rp
from microfit import histogram as hist

from microfit import variable_definitions as vdef
from microfit import selections

# %% [markdown]
# ###### Rest of code should go below. Separate code cells by type/function, i.e. code that loads data should be separated from code that plots the data

# %%
RUN = ["1"] 
rundata_numu, mc_weights_numu, data_pot_numu = dl.load_runs(
    RUN,
    
    data="opendata_bnb",  # which data to load
    # truth_filtered_sets=["nue", "drt", "nc_pi0", "cc_pi0", "cc_nopi", "cc_cpi", "nc_nopi", "nc_cpi"],
    
    truth_filtered_sets=["nue", "drt"], # Which truth-filtered MC sets to load in addition to the main MC set.
    #At least nu_e and dirt are highly recommended because the statistics at the final level of the selection are very low.
    
    # Choose which additional variables to load. Which ones are required may
    # depend on the selection you wish to apply.
    loadshowervariables=True,
    loadsystematics=True,
    loadnumuvariables=True,
    
    use_bdt=False, # Default is set to true; include this if not using
    
    # set this to true to let the data loading function know that we are loading numu
    numupresel=True,
    
    # Since this is Open Data, we are allowed to unblind the data. By default, the data is blinded.
    blinded=False,
    
    # With the cache enabled, by default the loaded dataframes will be stored as HDF5 files
    # in the 'cached_dataframes' folder. This will speed up subsequent loading of the same data.
    enable_cache=True,
)
# Out:
# Loading run 1
# /exp/uboone/app/users/cthorpe/miniforge3/envs/python3LEE/lib/python3.7/site-packages/awkward/array/jagged.py:1043: RuntimeWarning: overflow encountered in power
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /exp/uboone/app/users/cthorpe/miniforge3/envs/python3LEE/lib/python3.7/site-packages/uproot/tree.py in get(self, name, recursive, filtername, filtertitle, aliases)
#     388         try:
# --> 389             return self._branchlookup[name]
#     390         except KeyError:
#
# KeyError: b'shr2_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6450/3426788273.py in <module>
#      25     # With the cache enabled, by default the loaded dataframes will be stored as HDF5 files
#      26     # in the 'cached_dataframes' folder. This will speed up subsequent loading of the same data.
# ---> 27     enable_cache=True,
#      28 )
#
# /exp/uboone/app/users/jbtyler1/PELEE/data_loading.py in load_runs(run_numbers, **load_run_kwargs)
#    2588     for run in run_numbers:
#    2589         print("Loading run",run)
# -> 2590         runsdata[f"{run}"], weights[f"{run}"], data_pots[run_numbers.index(run)] = _load_run(run, **load_run_kwargs)
#    2591     pot_sum = np.sum(data_pots)
#    2592     rundict = runsdata[f"{run_numbers[0]}"]
#
# /exp/uboone/app/users/jbtyler1/PELEE/data_loading.py in _load_run(run_number, data, truth_filtered_sets, blinded, load_lee, use_new_signal_model, numupresel, **load_sample_kwargs)
#    2267         data_df = None
#    2268     else:
# -> 2269         data_df = load_sample(run_number, category, data, **load_sample_kwargs)
#    2270         data_df["weights"] = 1.0
#    2271     data_pot, data_trig = get_pot_trig(run_number, category, data)
#
# /exp/uboone/app/users/jbtyler1/PELEE/data_loading.py in wrapper(enable_cache, cache_dir, overwrite, *args, **kwargs)
#      79                 logger.debug(f"Overwriting cache file: {hdf_filepath}")
#      80             logger.debug(f"Calculating dataframe and saving to cache: {hdf_filepath}")
# ---> 81             df = func(*args, **kwargs)
#      82             assert isinstance(df, pd.DataFrame), "Output should be a pandas DataFrame"
#      83             df.to_hdf(hdf_filepath, key="data", mode="w")
#
# /exp/uboone/app/users/jbtyler1/PELEE/data_loading.py in load_sample(run_number, category, dataset, append, variation, loadsystematics, loadpi0variables, loadshowervariables, loadrecoveryvars, loadnumuvariables, use_lee_weights, use_bdt, pi0scaling, load_crt_vars, load_numu_tki, full_path, keep_columns)
#    2184             process_uproot_numu(up, df)
#    2185         if loadshowervariables:
# -> 2186             process_uproot_shower_variables(up, df)
#    2187         if loadrecoveryvars:
#    2188             if use_buggy_energy_estimator:
#
# /exp/uboone/app/users/jbtyler1/PELEE/data_loading.py in process_uproot_shower_variables(up, df)
#     892     # do the best we can to get the right shr2_id
#     893     #
# --> 894     shr2_id_corr = up.array("shr2_id") - 1  # I think we need this -1 to get the right result
#     895     shr2_id_appr = get_idx_from_vec_sort(-2, pfnhits_v, shr_mask)
#     896     shr2_id = np.where((shr2_id_corr >= 0) & (shr2_id_corr < df["n_showers_tot"]), shr2_id_corr, shr2_id_appr)
#
# /exp/uboone/app/users/cthorpe/miniforge3/envs/python3LEE/lib/python3.7/site-packages/uproot/tree.py in array(self, branch, interpretation, entrystart, entrystop, flatten, awkwardlib, cache, basketcache, keycache, executor, blocking)
#     502     def array(self, branch, interpretation=None, entrystart=None, entrystop=None, flatten=False, awkwardlib=None, cache=None, basketcache=None, keycache=None, executor=None, blocking=True):
#     503         awkward = _normalize_awkwardlib(awkwardlib)
# --> 504         branches = list(self._normalize_branches(branch, awkward))
#     505         if len(branches) == 1:
#     506             if interpretation is None:
#
# /exp/uboone/app/users/cthorpe/miniforge3/envs/python3LEE/lib/python3.7/site-packages/uproot/tree.py in _normalize_branches(self, arg, awkward, allownone, allowcallable, allowdict, allowstring, aliases)
#     821
#     822         elif allowstring and isinstance(arg, string_types):
# --> 823             for x in self._normalize_branches([arg], awkward):
#     824                 yield x
#     825
#
# /exp/uboone/app/users/cthorpe/miniforge3/envs/python3LEE/lib/python3.7/site-packages/uproot/tree.py in _normalize_branches(self, arg, awkward, allownone, allowcallable, allowdict, allowstring, aliases)
#     856
#     857                     else:
# --> 858                         branch = self.get(word, aliases=aliases)
#     859                         interpretation = interpret(branch, awkward)
#     860                         if interpretation is None:
#
# /exp/uboone/app/users/cthorpe/miniforge3/envs/python3LEE/lib/python3.7/site-packages/uproot/tree.py in get(self, name, recursive, filtername, filtertitle, aliases)
#     393                     self._branchlookup[name] = b
#     394                     return b
# --> 395             raise uproot.rootio._KeyError("not found: {0}\n in file: {1}".format(repr(name), self._context.sourcepath))
#     396
#     397     def __contains__(self, name):
#
# KeyError: not found: b'shr2_id'
#  in file: /exp/uboone/data/users/cthorpe/PELEE_2023_Samples/run1/numupresel/data_bnb_mcc9.1_v08_00_00_25_reco2_C1_beam_good_reco2_5e19.root

# %%
selection = "OnePT"
preselection = "OneP"

for binning_def in vdef.variables_1e1p:
    # some binning definitions have more than 4 elements,
    # we ignore the last ones for now
    binning = hist.Binning.from_config(*binning_def[:4])
    #binning = hist.Binning.from_config(*binning_def)
    signal_generator = hist.RunHistGenerator(
        rundata_numu,
        binning,
        data_pot=data_pot_numu,
        selection=selection,
        preselection=preselection,
        sideband_generator=None,
        uncertainty_defaults=None,
    )
    plotter = rp.RunHistPlotter(signal_generator)
    axes = plotter.plot(
        category_column="category_1e1p",
        include_multisim_errors=True,
        add_ext_error_floor=False,
#        show_data_mc_ratio=True,
    )
    #plt.savefig(f'plots/microfit_1e1p_{binning_def[0]}_{preselection}_{selection}.pdf', bbox_inches='tight')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_22070/1618612878.py in <module>
#      14         preselection=preselection,
#      15         sideband_generator=None,
# ---> 16         uncertainty_defaults=None,
#      17     )
#      18     plotter = rp.RunHistPlotter(signal_generator)
#
# /exp/uboone/app/users/jbtyler1/PELEE/microfit/histogram/run_hist_generator.py in __init__(self, rundata_dict, binning, selection, preselection, data_pot, sideband_generator, uncertainty_defaults, parameters, detvar_data, mc_hist_generator_cls, extra_mc_covariance, extra_background_fractional_error, showdata, **mc_hist_generator_kwargs)
#      93         # the selection cannot be changed later to include events that were filtered away
#      94         # here.
# ---> 95         query = get_selection_query(selection, preselection)
#      96         self.selection = selection
#      97         self.preselection = preselection
#
# /exp/uboone/app/users/jbtyler1/PELEE/microfit/selections.py in get_selection_query(selection, preselection, extra_queries)
#     737         return None
#     738     presel_query = preselection_categories[preselection]["query"]
# --> 739     sel_query = selection_categories[selection]["query"]
#     740
#     741     if presel_query is None:
#
# KeyError: 'OnePT'

# %%
print(rundata.keys())
print(type(rundata['mc']))
rundata['mc'].loc[:, ('reco_e', 'trk_theta')].head(60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_22070/1231551671.py in <module>
# ----> 1 print(rundata.keys())
#       2 print(type(rundata['mc']))
#       3 rundata['mc'].loc[:, ('reco_e', 'trk_theta')].head(60)
#
# NameError: name 'rundata' is not defined
