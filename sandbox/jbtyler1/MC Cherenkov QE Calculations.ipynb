# %% [markdown]
# # Setup Code

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("../../")
#from microfit import run_plotter as rp
#from microfit import histogram as hist
import math
from microfit import run_plotter as rp
from microfit import histogram as hist

from microfit import variable_definitions as vdef
from microfit import selections

#data_pot = 1.67e+20 # Run 1 bnb (numu) OG Test00
data_pot = 1.1076e+21 # Runs 1-5 numu

rundata = {
    'data': None,
    'ext': None,
    'mc': None,
    'nue': None,
    'drt': None
}

for key, df in rundata.items():
    if key != 'data':
        print(key)
        rundata[key] = pd.read_pickle(f'/exp/uboone/data/users/jbtyler1/PELEE/tmp_pickles/{key}.pkl')
# Out:
# ext
# mc
# nue
# drt

# %%
df = rundata["mc"]

# %% [markdown]
# # Tests & Info

# %%
#type(df)

# %%
#df.columns

# %%
#'mc_pdg' in df.columns
# Out:
# True

# %%
#df["mc_pdg"]
# Out:
# entry
# 0        [11, 2212, 2212, 2212, 2212, 2112, 2112, 2112,...
# 1                                               [11, 2212]
# 2        [11, 2212, 2212, 2212, 2212, 2212, 2212, 2212,...
# 3                         [11, 2212, 2212, 211, -211, 111]
# 4                                   [11, 2112, 2212, 2212]
#                                ...
# 54736                   [11, 2112, 2112, 2112, 2112, 2112]
# 54737                    [11, 2212, 2112, 211, 2112, 2212]
# 54738                                [11, 2112, 2212, 111]
# 54739                                           [11, 2212]
# 54740                                      [11, 2112, 211]
# Name: mc_pdg, Length: 54741, dtype: object

# %% [markdown]
# # Plotting Code

# %%
myhisto_2d2 = plt.hist2d(df["theta"], df["SubChrnkv_E"], bins=30, range=[[0.00001,2],[0.00001,0.6]])
plt.colorbar()
plt.xlabel("Theta [Radians]")
plt.ylabel("Sub-Cherenkov KE total [GeV]")
# Out:
# Text(0, 0.5, 'Sub-Cherenkov KE total [GeV]')

# %%
myhisto_1d21 = plt.hist(df["shr_theta"], bins=35, range=[0,3.5], log = False)
plt.xlabel("Shower Theta [Radians]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto_1d22 = plt.hist(df["theta"], bins=35, range=[0,3.5], log = False)
plt.xlabel("Theta [Radians]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto_1d23 = plt.hist(df["trk_theta"], bins=35, range=[0,3.5], log = False)
plt.xlabel("Track Theta [Radians]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto_1d24 = plt.hist(df["shr_energy_cali"], bins=40, range=[0,4], log = True)
plt.xlabel("Shower Energy [GeV]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto_1d25 = plt.hist(df["muon_theta"], bins=20, range=[-1,1], log = False)
plt.xlabel("Muon Theta [Radians]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto_1d28 = plt.hist(df["reco_e_qe_l"], bins=50, range=[0.2,3], log = False)
plt.xlabel("Reconstructed Quasi-Elastic Energy [GeV]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto_1d28 = plt.hist(df["reco_e_qe"], bins=10, range=[0.2,1.5], log = False)
plt.xlabel("Reconstructed Quasi-Elastic Energy [GeV]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto_1d29 = plt.hist(df["EvQEle"], bins=10, range=[0.2,1.5], log = False)
plt.xlabel("MC Truth Electron Neutrino Quasi-Elastic Energy [GeV]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto_1d30 = plt.hist(df["EvQElu"], bins=50, range=[0.2,3], log = False)
plt.xlabel("MC Truth Muon Neutrino Quasi-Elastic Energy [GeV]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')
