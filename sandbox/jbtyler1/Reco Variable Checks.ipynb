# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("../../")
#from microfit import run_plotter as rp
#from microfit import histogram as hist
import math
from microfit import run_plotter as rp
from microfit import histogram as hist

from microfit import variable_definitions as vdef
from microfit import selections

data_pot = 1.67e+20 # Run 1 bnb (numu) OG Test00
#data_pot = 1.1076e+21 # Runs 1-5 numu

rundata = {
    'data': None,
    'ext': None,
    'mc': None,
    'nue': None,
    'drt': None
}

for key, df in rundata.items():
    if key != 'data':
        print(key)
        rundata[key] = pd.read_pickle(f'/exp/uboone/data/users/jbtyler1/PELEE/tmp_pickles/{key}.pkl')
# Out:
# ext
# mc
# nue
# drt

# %%
df = rundata["mc"]

# %%
#List of reco variables
#shr_energy_cali
#shr_px
#shr_py
#shr_pz
#shr_energy
#reco_KE_shr
#reco_EvQEle
#nshr_visible

# %%
myhisto01 = plt.hist(df["reco_KE_shr"], bins=50, range=(0,5), log=True)
plt.xlabel("Reco Shower KE Total [GeV]")
plt.ylabel("Count (Log-Scale)")
# Out:
# Text(0, 0.5, 'Count (Log-Scale)')

# %%
myhisto02 = plt.hist(df["reco_KE_shr"], bins=50, range=(0,5), log=False)
plt.xlabel("Reco Shower KE total [GeV]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto03 = plt.hist(df["reco_EvQEle"], bins=26, range=(0.2,1.5), log=True)
plt.xlabel("Reconstructed EvQEle [GeV]")
plt.ylabel("Count (Log-Scale)")
# Out:
# Text(0, 0.5, 'Count (Log-Scale)')

# %%
myhisto04 = plt.hist(df["reco_EvQEle"], bins=26, range=(0.2,1.5), log=False)
plt.xlabel("Reconstructed EvQEle [GeV]")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
myhisto04 = plt.hist(df["shr_score"], bins=20, range=(0,0.5), log=False)
plt.xlabel("Shower Score")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')
