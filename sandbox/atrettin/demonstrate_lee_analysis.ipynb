# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
sys.path.append("../../")
from plotting.analysis import MultibandAnalysis

# %%
from importlib import reload
import logging
reload(logging)

logging.basicConfig(level=logging.DEBUG)

# %%
import toml


toml_string = """
[sideband_data]
run_numbers = [3]
data = "opendata_bnb"
blinded = false
truth_filtered_sets = ["nue", "drt"]
loadshowervariables = false
loadsystematics = true
use_bdt = false
loadpi0variables = false
numupresel = true
load_crt_vars = true
loadnumuvariables = true
enable_cache = true

[sideband]
selection = "NUMUCRT"
preselection = "NUMU"

[sideband.binning]
variable = "neutrino_energy"
n_bins = 14
limits = [0.15, 1.55]
label = "Neutrino reconstructed energy [GeV]"

[sideband.uncertainties]
include_multisim_errors = true
add_ext_error_floor = false
use_sideband = false

[signal_data]
run_numbers = [1]
data = "opendata_bnb"
blinded = false
truth_filtered_sets = ["nue"]
loadshowervariables = true
loadsystematics = true
loadpi0variables = true
loadrecoveryvars = true
load_lee = true
enable_cache=true

[[signal]]

    selection = "NPBDT"
    preselection = "NP"
    mc_hist_generator_cls = "SignalOverBackgroundGenerator"

    [signal.uncertainties]
    include_multisim_errors = true
    add_ext_error_floor = false
    use_sideband = true

    [signal.binning]
    variable = "reco_e"
    n_bins = 17
    limits = [0.01, 2.39]
    label = "Reconstructed Energy [ GeV ]"

    [[signal.parameter]]
    name = "signal_strength"
    value = 1.0
    bounds = [0.0, 10.0]

    # [[signal.parameter]]
    # name = "delta_gamma"
    # value = 0.0
    # bounds = [-1.0, 1.0]

[[signal]]

    selection = "ZPBDT"
    preselection = "ZP"
    mc_hist_generator_cls = "SignalOverBackgroundGenerator"

    [signal.uncertainties]
    include_multisim_errors = true
    add_ext_error_floor = false
    use_sideband = true

    [signal.binning]
    variable = "reco_e"
    n_bins = 17
    limits = [0.01, 2.39]
    label = "Reconstructed Energy [ GeV ]"

    [[signal.parameter]]
    name = "signal_strength"
    value = 1.0
    bounds = [0.0, 10.0]

    # [[signal.parameter]]
    # name = "delta_gamma"
    # value = 0.0
    # bounds = [-1.0, 1.0]
"""

lee_analysis = MultibandAnalysis(toml.loads(toml_string))
# Out:
# Making generator for selection NUMUCRT and preselection NUMU
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='Neutrino reconstructed energy [GeV]', is_log=False)
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='Neutrino reconstructed energy [GeV]', is_log=False)
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='Neutrino reconstructed energy [GeV]', is_log=False)
# Loading lee sample
# Making generator for selection NPBDT and preselection NP
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='reco_e', bin_edges=array([0.01, 0.15, 0.29, 0.43, 0.57, 0.71, 0.85, 0.99, 1.13, 1.27, 1.41,
#        1.55, 1.69, 1.83, 1.97, 2.11, 2.25, 2.39]), label='Reconstructed Energy [ GeV ]', is_log=False)
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='reco_e', bin_edges=array([0.01, 0.15, 0.29, 0.43, 0.57, 0.71, 0.85, 0.99, 1.13, 1.27, 1.41,
#        1.55, 1.69, 1.83, 1.97, 2.11, 2.25, 2.39]), label='Reconstructed Energy [ GeV ]', is_log=False)
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='reco_e', bin_edges=array([0.01, 0.15, 0.29, 0.43, 0.57, 0.71, 0.85, 0.99, 1.13, 1.27, 1.41,
#        1.55, 1.69, 1.83, 1.97, 2.11, 2.25, 2.39]), label='Reconstructed Energy [ GeV ]', is_log=False)
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='reco_e', bin_edges=array([0.01, 0.15, 0.29, 0.43, 0.57, 0.71, 0.85, 0.99, 1.13, 1.27, 1.41,
#        1.55, 1.69, 1.83, 1.97, 2.11, 2.25, 2.39]), label='Reconstructed Energy [ GeV ]', is_log=False)
# Making generator for selection ZPBDT and preselection ZP
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='reco_e', bin_edges=array([0.01, 0.15, 0.29, 0.43, 0.57, 0.71, 0.85, 0.99, 1.13, 1.27, 1.41,
#        1.55, 1.69, 1.83, 1.97, 2.11, 2.25, 2.39]), label='Reconstructed Energy [ GeV ]', is_log=False)
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='reco_e', bin_edges=array([0.01, 0.15, 0.29, 0.43, 0.57, 0.71, 0.85, 0.99, 1.13, 1.27, 1.41,
#        1.55, 1.69, 1.83, 1.97, 2.11, 2.25, 2.39]), label='Reconstructed Energy [ GeV ]', is_log=False)
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='reco_e', bin_edges=array([0.01, 0.15, 0.29, 0.43, 0.57, 0.71, 0.85, 0.99, 1.13, 1.27, 1.41,
#        1.55, 1.69, 1.83, 1.97, 2.11, 2.25, 2.39]), label='Reconstructed Energy [ GeV ]', is_log=False)
# DEBUG:plotting.histogram:Creating histogram generator for with binning: Binning(variable='reco_e', bin_edges=array([0.01, 0.15, 0.29, 0.43, 0.57, 0.71, 0.85, 0.99, 1.13, 1.27, 1.41,
#        1.55, 1.69, 1.83, 1.97, 2.11, 2.25, 2.39]), label='Reconstructed Energy [ GeV ]', is_log=False)

# %%
lee_analysis.parameters
# Out:
# Parameters:
# Name	Value	Unit	Bounds
# -------------------------------
# signal_strength	1		(0, 10)

# %%
lee_analysis.plot_sideband()
# Out:
# DEBUG:plotting.histogram:Generating histogram with query: nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and n_muons_tot > 0 and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5.
# DEBUG:plotting.histogram:Total number of events after filtering: 5258
# DEBUG:plotting.histogram:Generated histogram: Histogram(binning=Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='Neutrino reconstructed energy [GeV]', is_log=False), bin_counts=[3.729845884867845+/-0.2028768706131356
#  9.909472202991754+/-0.3306833704195315
#  12.800654516113783+/-0.37584015774423146
#  9.788086686030223+/-0.32865178622305236
#  6.709308573965245+/-0.2720983929182721
#  4.160212717738318+/-0.21426185581270205
#  2.968427642099755+/-0.1809882276191708
#  2.1628692113440593+/-0.15449065795313072
#  1.125574793658643+/-0.11144851163774645
#  0.8386635717456556+/-0.09620130939125786
#  0.6731378667958552+/-0.08618647222921749
#  0.4634719738594413+/-0.0715152781800473
#  0.242771033926374+/-0.051758958343489654
#  0.17656075194645382+/-0.04414018798660878], label=, tex=)
# DEBUG:plotting.histogram:Generating histogram with query: nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and n_muons_tot > 0 and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5. & category == '2'
# DEBUG:plotting.histogram:Total number of events after filtering: 49907
# DEBUG:plotting.histogram:Generated histogram: Histogram(binning=Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='Neutrino reconstructed energy [GeV]', is_log=False), bin_counts=[5.054262543295071+/-0.2716708340043876
#  20.97930951608205+/-0.5453795528246771
#  36.15753733389557+/-0.6719171964069606
#  49.3128288620447+/-0.8116406623097204
#  48.17100446542696+/-0.7922106335331361
#  47.407830846529805+/-0.7891461523914587
#  42.58019783831031+/-0.754232033269879
#  35.95350599988262+/-0.7299596512865585
#  29.698882416469644+/-0.6792700183484618
#  22.78697935755315+/-0.5619440183743144
#  16.964433975519796+/-0.4983017319512884
#  12.511247035143299+/-0.423353582563166
#  8.92934273348601+/-0.36097421826087644
#  6.209082171519697+/-0.27338021437692517], label=, tex=)
# DEBUG:plotting.histogram:Generating histogram with query: nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and n_muons_tot > 0 and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5. & category == '4'
# DEBUG:plotting.histogram:Total number of events after filtering: 3759
# DEBUG:plotting.histogram:Generated histogram: Histogram(binning=Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='Neutrino reconstructed energy [GeV]', is_log=False), bin_counts=
# DEBUG:plotting.histogram:Generated histogram: Histogram(binning=Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='Neutrino reconstructed energy [GeV]', is_log=False), bin_counts=[10.1002386006409+/-0.3960273861647504
#  33.25041019371633+/-0.6748378690944347
#  52.06246397120522+/-0.8424448514755551
#  64.10112695571999+/-0.9259501097436829
#  61.207570625886234+/-0.894080894047465
#  58.918034227908436+/-0.8866923260367165
#  53.64546436996426+/-0.868569724569714
#  46.15400901905383+/-1.2768794681286961
#  39.47654795300713+/-1.27180839829752
#  29.506095473852895+/-0.6135968455688371
#  22.866400806618856+/-0.5473174965798999
#  17.468093497408688+/-0.48052856477374295
#  12.269980814835378+/-0.3964537878513476
#  9.113544416497348+/-0.32297568181499153], label=, tex=)
# DEBUG:plotting.histogram:Calculated covariance matrix for weightsGenie.
# DEBUG:plotting.histogram:Bin-wise error contribution: [1.39119562 4.53196143 6.87663951 8.45890554 8.02430776 7.72829678
#  7.28271354 6.67825494 5.76578684 4.22523906 3.35157638 2.61189297
#  1.78445643 1.36413009]
# DEBUG:plotting.histogram:Multisim histogram found in cache.
# DEBUG:plotting.histogram:Multisim histogram found in cache.
# DEBUG:plotting.histogram:Calculating unisim uncertainties
# DEBUG:plotting.histogram:Calculated histogram for knobRPAup, universe 0 with bin counts:
# [10.97276128 35.07676632 53.93825872 65.88268531 62.14177985 59.8481884
#  54.38796417 45.74948247 39.05967126 30.01705649 23.29347951 17.77582153
#  12.47769878  9.34636112].
# DEBUG:plotting.histogram:Calculated histogram for knobRPAup, universe 1 with bin counts:
# [ 9.22771589 31.42405405 50.18666923 62.31956855 60.2733615  57.98788004
#  52.90296459 44.55877894 37.89366798 28.99513444 22.43932211 17.16036546
#  12.06226285  8.88072773].
# DEBUG:plotting.histogram:Bin-wise error contribution for knob knobRPA: [0.87252269 1.82635613 1.87579474 1.78155838 0.93420917 0.93015418
#  0.74249979 1.16370115 1.15743146 0.51096103 0.4270787  0.30772803
#  0.20771797 0.2328167 ]
# DEBUG:plotting.histogram:Calculated histogram for knobCCMECup, universe 0 with bin counts:
# [10.52646364 34.55560557 53.35669873 64.64950256 61.95292558 59.53375195
#  54.11441455 44.78619649 37.3392899  29.95903598 23.02655094 17.40980899
#  12.23425514  9.32996   ].
# DEBUG:plotting.histogram:Bin-wise error contribution for knob knobCCMEC: [0.42622504 1.30519537 1.29423476 0.5483756  0.74535496 0.61571772
#  0.46895018 1.36781253 2.13725805 0.45294051 0.16015013 0.05828451
#  0.03572567 0.21641558]
# DEBUG:plotting.histogram:Calculated histogram for knobAxFFCCQEup, universe 0 with bin counts:
# [10.10023858 33.25041018 52.06246397 64.10112693 61.20757067 58.91803422
#  53.64546438 45.1541307  38.47666962 29.50609547 22.86640081 17.4680935
#  12.26998081  9.11354442].
# DEBUG:plotting.histogram:Bin-wise error contribution for knob knobAxFFCCQE: [2.75041539e-08 2.47935266e-08 2.13757479e-08 3.47218344e-08
#  5.30539021e-08 2.23263358e-08 2.25956481e-08 9.99878316e-01
#  9.99878332e-01 2.21485361e-08 2.15303063e-08 2.11051178e-08
#  2.10734389e-08 2.15151592e-08]
# DEBUG:plotting.histogram:Calculated histogram for knobVecFFCCQEup, universe 0 with bin counts:
# [10.10023858 33.25041018 52.06246397 64.10112693 61.20757067 58.91803422
#  53.64546438 45.1541307  38.47666962 29.50609547 22.86640081 17.4680935
#  12.26998081  9.11354442].
# DEBUG:plotting.histogram:Bin-wise error contribution for knob knobVecFFCCQE: [2.75041539e-08 2.47935266e-08 2.13757479e-08 3.47218344e-08
#  5.30539021e-08 2.23263358e-08 2.25956481e-08 9.99878316e-01
#  9.99878332e-01 2.21485361e-08 2.15303063e-08 2.11051178e-08
#  2.10734389e-08 2.15151592e-08]
# DEBUG:plotting.histogram:Calculated histogram for knobDecayAngMECup, universe 0 with bin counts:
# [10.10023858 33.25041018 52.06246397 64.10112693 61.20757067 58.91803422
#  53.64546438 45.1541307  38.47666962 29.50609547 22.86640081 17.4680935
#  12.26998081  9.11354442].
# DEBUG:plotting.histogram:Bin-wise error contribution for knob knobDecayAngMEC: [2.75041539e-08 2.47935266e-08 2.13757479e-08 3.47218344e-08
#  5.30539021e-08 2.23263358e-08 2.25956481e-08 9.99878316e-01
#  9.99878332e-01 2.21485361e-08 2.15303063e-08 2.11051178e-08
#  2.10734389e-08 2.15151592e-08]
# DEBUG:plotting.histogram:Calculated histogram for knobThetaDelta2Npiup, universe 0 with bin counts:
# [10.10023858 33.25041018 52.06246397 64.10112693 61.20757067 58.91803422
#  53.64546438 45.1541307  38.47666962 29.50609547 22.86640081 17.4680935
#  12.26998081  9.11354442].
# DEBUG:plotting.histogram:Bin-wise error contribution for knob knobThetaDelta2Npi: [2.75041539e-08 2.47935266e-08 2.13757479e-08 3.47218344e-08
#  5.30539021e-08 2.23263358e-08 2.25956481e-08 9.99878316e-01
#  9.99878332e-01 2.21485361e-08 2.15303063e-08 2.11051178e-08
#  2.10734389e-08 2.15151592e-08]
# DEBUG:plotting.histogram:Generating histogram with query: nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and nslice == 1 and ( (_opfilter_pe_beam > 0 and _opfilter_pe_veto < 20) or bnbdata == 1 or extdata == 1) and reco_nu_vtx_sce_x > 5 and reco_nu_vtx_sce_x < 251.  and reco_nu_vtx_sce_y > -110 and reco_nu_vtx_sce_y < 110.  and reco_nu_vtx_sce_z > 20 and reco_nu_vtx_sce_z < 986.  and (reco_nu_vtx_sce_z < 675 or reco_nu_vtx_sce_z > 775)  and topological_score > 0.06  and n_muons_tot > 0 and (crtveto != 1 or crthitpe < 100) and _closestNuCosmicDist > 5.
# DEBUG:plotting.histogram:Total number of events after filtering: 626
# DEBUG:plotting.histogram:Generated histogram: Histogram(binning=Binning(variable='neutrino_energy', bin_edges=array([0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 1.05, 1.15,
#        1.25, 1.35, 1.45, 1.55]), label='Neutrino reconstructed energy [GeV]', is_log=False), bin_counts=[13.0+/-3.605551275463989 29.0+/-5.385164807134504
#  74.0+/-8.602325267042627 76.0+/-8.717797887081348
#  78.0+/-8.831760866327848 70.0+/-8.366600265340756
#  61.0+/-7.810249675906654 52.0+/-7.211102550927978
#  34.0+/-5.830951894845301 33.0+/-5.744562646538029
#  24.0+/-4.898979485566356 13.0+/-3.605551275463989
#  10.0+/-3.1622776601683795 8.0+/-2.8284271247461903], label=, tex=)

# %%
type(lee_analysis._signal_generators[1].mc_hist_generator)
# Out:
# plotting.signal_generators.SignalOverBackgroundGenerator

# %%
lee_analysis.parameters["signal_strength"].value = 1.0
# lee_analysis.parameters["delta_gamma"].value = 0.0

# %%
lee_analysis.plot_signals()
# Out:
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
# DEBUG:plotting.histogram:Histogram found in cache.
# DEBUG:plotting.histogram:Using cached total covariance matrix.
